# %% [markdown]
# Fraud detection capstone project, using Kaggle big dataset of transactions.

# %%
import pandas as pd

# %%
# Loading data
df = pd.read_excel('bank.xlsx')

# %% [markdown]
# Data preprocessing (Cleanining, future engineering, normalization and encoding)

# %%
print(df.isna().sum())
# Out:
# Account No                  0
# DATE                        0
# TRANSACTION DETAILS      2499
# CHQ.NO.                115296
# VALUE DATE                  0
# WITHDRAWAL AMT          62652
# DEPOSIT AMT             53549
# BALANCE AMT                 0
# .                           0
# dtype: int64
